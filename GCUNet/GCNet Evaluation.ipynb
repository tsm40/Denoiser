# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Denoiser/GCNet/GCNet Training
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1QYFt1W2KnuJT1hW_lTDccaNsVqlZ_8_P/Denoiser/GCNet/GCNet Training
#  checkpoints		  evaluation.m		    model	       train.py
#  data_RGB.py		  evaluation.py		    __pycache__        utils
#  dataset_RGB.py		  GCDownsample.ipynb	    README.md	       warmup_scheduler
#  datasets		 'GCNet Evaluation.ipynb'   requirements.txt
#  demo_any_resolution.py   GCNet.ipynb		    result
#  demo.py		  generate_patches.py	    training.yaml

# %%
# !pip install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install -U openmim
# !mim install mmcv==1.4.0
# !pip install pytorch_msssim
# !pip install tensorboardX
# !pip install thop
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...

# %%
import torch
import torch.nn as nn

# Check device availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("You are using device: %s" % device)
# Out:
# You are using device: cuda

# %% [markdown]
# ###Generate denoised images using the best pre-trained GCNet model
# The denoised images will be used for evaluation later.

# %%
# !python demo_any_resolution.py --input_dir 'result/datasets/Kodak24_noisy/sigma10/' --stride 128 --result_dir 'result/denoised/Kodak24/sigma10' --weights 'checkpoints/Denoising/models/model_bestPSNR.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# restoring images......
# Files saved at result/denoised/Kodak24/sigma10

# %%
# !python demo_any_resolution.py --input_dir 'result/datasets/Kodak24_noisy/sigma30/' --stride 128 --result_dir 'result/denoised/Kodak24/sigma30' --weights 'checkpoints/Denoising/models/model_bestPSNR.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# restoring images......
# Files saved at result/denoised/Kodak24/sigma30

# %%
# !python demo_any_resolution.py --input_dir 'result/datasets/Kodak24_noisy/sigma50/' --stride 128 --result_dir 'result/denoised/Kodak24/sigma50' --weights 'checkpoints/Denoising/models/model_bestPSNR.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# restoring images......
# Files saved at result/denoised/Kodak24/sigma50

# %%
# !python demo_any_resolution.py --input_dir 'result/datasets/CBSD68/CBSD68/noisy15/' --stride 128 --result_dir 'result/denoised/CBSD68/sigma15' --weights 'checkpoints/Denoising/models/model_bestPSNR.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# restoring images......
# Files saved at result/denoised/CBSD68/sigma15

# %%
# !python demo_any_resolution.py --input_dir 'result/datasets/CBSD68/CBSD68/noisy25/' --stride 128 --result_dir 'result/denoised/CBSD68/sigma25' --weights 'checkpoints/Denoising/models/model_bestPSNR.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# restoring images......
# Files saved at result/denoised/CBSD68/sigma25

# %%
# !python demo_any_resolution.py --input_dir 'result/datasets/CBSD68/CBSD68/noisy50/' --stride 128 --result_dir 'result/denoised/CBSD68/sigma50' --weights 'checkpoints/Denoising/models/model_bestPSNR.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# restoring images......
# Files saved at result/denoised/CBSD68/sigma50

# %% [markdown]
# ###Evaluate different datasets

# %%
# !python evaluation.py --path_gt 'result/datasets/Kodak24/' --path_noise 'result/datasets/Kodak24_noisy/sigma10/' --path_denoise 'result/denoised/Kodak24/sigma10'
# Out:
# GT: kodim01.png
# Noise: kodim01.png
# Denoise: kodim01.png
#
#   Noise PSNR  = 28.1277 dB ---------- 1/24
#   Noise SSIM  = 0.8719     ---------- 1/24
# Denoise PSNR* = 29.1814 dB ---------- 1/24
# Denoise SSIM* = 0.8927     ---------- 1/24
# ----------------------------------------------
# GT: kodim02.png
# Noise: kodim02.png
# Denoise: kodim02.png
#
#   Noise PSNR  = 28.1735 dB ---------- 2/24
#   Noise SSIM  = 0.6930     ---------- 2/24
# Denoise PSNR* = 29.3469 dB ---------- 2/24
# Denoise SSIM* = 0.7924     ---------- 2/24
# ----------------------------------------------
# GT: kodim03.png
# Noise: kodim03.png
# Denoise: kodim03.png
#
#   Noise PSNR  = 28.1873 dB ---------- 3/24
#   Noise SSIM  = 0.6665     ---------- 3/24
# Denoise PSNR* = 31.1038 dB ---------- 3/24
# Denoise SSIM* = 0.8803     ---------- 3/24
# ----------------------------------------------
# GT: kodim04.png
# Noise: kodim04.png
# Denoise: kodim04.png
#
#   Noise PSNR  = 28.1382 dB ---------- 4/24
# ...

# %%
# !python evaluation.py --path_gt 'result/datasets/Kodak24/' --path_noise 'result/datasets/Kodak24_noisy/sigma30/' --path_denoise 'result/denoised/Kodak24/sigma30'
# Out:
# GT: kodim01.png
# Noise: kodim01.png
# Denoise: kodim01.png
#
#   Noise PSNR  = 18.7444 dB ---------- 1/24
#   Noise SSIM  = 0.5550     ---------- 1/24
# Denoise PSNR* = 26.1340 dB ---------- 1/24
# Denoise SSIM* = 0.7767     ---------- 1/24
# ----------------------------------------------
# GT: kodim02.png
# Noise: kodim02.png
# Denoise: kodim02.png
#
#   Noise PSNR  = 19.1375 dB ---------- 2/24
#   Noise SSIM  = 0.2625     ---------- 2/24
# Denoise PSNR* = 27.6213 dB ---------- 2/24
# Denoise SSIM* = 0.7110     ---------- 2/24
# ----------------------------------------------
# GT: kodim03.png
# Noise: kodim03.png
# Denoise: kodim03.png
#
#   Noise PSNR  = 18.8375 dB ---------- 3/24
#   Noise SSIM  = 0.2549     ---------- 3/24
# Denoise PSNR* = 28.7376 dB ---------- 3/24
# Denoise SSIM* = 0.7543     ---------- 3/24
# ----------------------------------------------
# GT: kodim04.png
# Noise: kodim04.png
# Denoise: kodim04.png
#
#   Noise PSNR  = 18.8303 dB ---------- 4/24
# ...

# %%
# !python evaluation.py --path_gt 'result/datasets/Kodak24/' --path_noise 'result/datasets/Kodak24_noisy/sigma50/' --path_denoise 'result/denoised/Kodak24/sigma50'
# Out:
# GT: kodim01.png
# Noise: kodim01.png
# Denoise: kodim01.png
#
#   Noise PSNR  = 14.6003 dB ---------- 1/24
#   Noise SSIM  = 0.3708     ---------- 1/24
# Denoise PSNR* = 23.6375 dB ---------- 1/24
# Denoise SSIM* = 0.6581     ---------- 1/24
# ----------------------------------------------
# GT: kodim02.png
# Noise: kodim02.png
# Denoise: kodim02.png
#
#   Noise PSNR  = 15.2271 dB ---------- 2/24
#   Noise SSIM  = 0.1417     ---------- 2/24
# Denoise PSNR* = 26.0445 dB ---------- 2/24
# Denoise SSIM* = 0.5994     ---------- 2/24
# ----------------------------------------------
# GT: kodim03.png
# Noise: kodim03.png
# Denoise: kodim03.png
#
#   Noise PSNR  = 14.7435 dB ---------- 3/24
#   Noise SSIM  = 0.1405     ---------- 3/24
# Denoise PSNR* = 26.0203 dB ---------- 3/24
# Denoise SSIM* = 0.6015     ---------- 3/24
# ----------------------------------------------
# GT: kodim04.png
# Noise: kodim04.png
# Denoise: kodim04.png
#
#   Noise PSNR  = 14.7789 dB ---------- 4/24
# ...

# %%
# !python evaluation.py --path_gt 'result/datasets/CBSD68/CBSD68/original_png/' --path_noise 'result/datasets/CBSD68/CBSD68/noisy15/' --path_denoise 'result/denoised/CBSD68/sigma15'
# Out:
# GT: 0000.png
# Noise: 0000.png
# Denoise: 0000.png
#
#   Noise PSNR  = 24.6540 dB ---------- 1/68
#   Noise SSIM  = 0.3862     ---------- 1/68
# Denoise PSNR* = 32.0083 dB ---------- 1/68
# Denoise SSIM* = 0.9172     ---------- 1/68
# ----------------------------------------------
# GT: 0001.png
# Noise: 0001.png
# Denoise: 0001.png
#
#   Noise PSNR  = 24.6201 dB ---------- 2/68
#   Noise SSIM  = 0.7416     ---------- 2/68
# Denoise PSNR* = 27.4921 dB ---------- 2/68
# Denoise SSIM* = 0.8390     ---------- 2/68
# ----------------------------------------------
# GT: 0002.png
# Noise: 0002.png
# Denoise: 0002.png
#
#   Noise PSNR  = 25.0746 dB ---------- 3/68
#   Noise SSIM  = 0.5267     ---------- 3/68
# Denoise PSNR* = 29.9983 dB ---------- 3/68
# Denoise SSIM* = 0.8518     ---------- 3/68
# ----------------------------------------------
# GT: 0003.png
# Noise: 0003.png
# Denoise: 0003.png
#
#   Noise PSNR  = 24.7124 dB ---------- 4/68
#   Noise SSIM  = 0.7278     ---------- 4/68
# ...

# %%
# !python evaluation.py --path_gt 'result/datasets/CBSD68/CBSD68/original_png/' --path_noise 'result/datasets/CBSD68/CBSD68/noisy25/' --path_denoise 'result/denoised/CBSD68/sigma25'
# Out:
# GT: 0000.png
# Noise: 0000.png
# Denoise: 0000.png
#
#   Noise PSNR  = 20.2296 dB ---------- 1/68
#   Noise SSIM  = 0.2043     ---------- 1/68
# Denoise PSNR* = 31.0449 dB ---------- 1/68
# Denoise SSIM* = 0.8624     ---------- 1/68
# ----------------------------------------------
# GT: 0001.png
# Noise: 0001.png
# Denoise: 0001.png
#
#   Noise PSNR  = 20.2838 dB ---------- 2/68
#   Noise SSIM  = 0.5595     ---------- 2/68
# Denoise PSNR* = 26.5810 dB ---------- 2/68
# Denoise SSIM* = 0.7993     ---------- 2/68
# ----------------------------------------------
# GT: 0002.png
# Noise: 0002.png
# Denoise: 0002.png
#
#   Noise PSNR  = 20.8933 dB ---------- 3/68
#   Noise SSIM  = 0.3303     ---------- 3/68
# Denoise PSNR* = 29.2675 dB ---------- 3/68
# Denoise SSIM* = 0.8063     ---------- 3/68
# ----------------------------------------------
# GT: 0003.png
# Noise: 0003.png
# Denoise: 0003.png
#
#   Noise PSNR  = 20.3895 dB ---------- 4/68
#   Noise SSIM  = 0.5500     ---------- 4/68
# ...

# %%
# !python evaluation.py --path_gt 'result/datasets/CBSD68/CBSD68/original_png/' --path_noise 'result/datasets/CBSD68/CBSD68/noisy50/' --path_denoise 'result/denoised/CBSD68/sigma50'
# Out:
# GT: 0000.png
# Noise: 0000.png
# Denoise: 0000.png
#
#   Noise PSNR  = 14.3608 dB ---------- 1/68
#   Noise SSIM  = 0.0805     ---------- 1/68
# Denoise PSNR* = 27.4105 dB ---------- 1/68
# Denoise SSIM* = 0.6213     ---------- 1/68
# ----------------------------------------------
# GT: 0001.png
# Noise: 0001.png
# Denoise: 0001.png
#
#   Noise PSNR  = 14.7665 dB ---------- 2/68
#   Noise SSIM  = 0.3106     ---------- 2/68
# Denoise PSNR* = 24.0687 dB ---------- 2/68
# Denoise SSIM* = 0.6734     ---------- 2/68
# ----------------------------------------------
# GT: 0002.png
# Noise: 0002.png
# Denoise: 0002.png
#
#   Noise PSNR  = 15.3327 dB ---------- 3/68
#   Noise SSIM  = 0.1394     ---------- 3/68
# Denoise PSNR* = 26.6420 dB ---------- 3/68
# Denoise SSIM* = 0.6423     ---------- 3/68
# ----------------------------------------------
# GT: 0003.png
# Noise: 0003.png
# Denoise: 0003.png
#
#   Noise PSNR  = 14.9554 dB ---------- 4/68
#   Noise SSIM  = 0.3076     ---------- 4/68
# ...
